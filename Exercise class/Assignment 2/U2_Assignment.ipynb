# %% [markdown]
# Name | Matr.Nr. | Due Date
# :--- | ---: | ---:
# Ayse Sude Baki | 12211229 | 07.11.2022, 08:00

# %% [markdown]
# <h1 style="color:rgb(0,120,170)">Hands-on AI I</h1>
# <h2 style="color:rgb(0,120,170)">Unit 2 &ndash; Reading, Handling and Visualization of Datasets</h2>

# %% [markdown]
# <b>Authors:</b> Brandstetter, Schäfl, Parada-Cabaleiro, Schörgenhumer<br>
# <b>Date:</b> 24-10-2022
#
# This file is part of the "Hands-on AI I" lecture material. The following copyright statement applies to all code within this file.
#
# <b>Copyright statement:</b><br>
# This material, no matter whether in printed or electronic form, may be used for personal and non-commercial educational use only. Any reproduction of this material, no matter whether as a whole or in parts, no matter whether in printed or in electronic form, requires explicit prior acceptance of the authors.

# %% [markdown]
# <h3 style="color:rgb(0,120,170)">How to use this notebook</h3>
#
# This notebook is designed to run from start to finish. There are different tasks (displayed in <span style="color:rgb(248,138,36)">orange boxes</span>) which require your contribution (in form of code, plain text, ...). Most/All of the supplied functions are imported from the file <code>u2_utils.py</code> which can be seen and treated as a black box. However, for further understanding, you can look at the implementations of the helper functions. In order to run this notebook, the packages which are imported at the beginning of <code>u2_utils.py</code> need to be installed.

# %%
import u2_utils as u2
import IPython.display as ipd
import numpy as np
import seaborn as sns
import spacy
from matplotlib.image import imread

sns.set()

u2.check_module_versions()
# Out:
# Installed Python version: 3.9 (✓)
# Installed numpy version: 1.21.5 (✓)
# Installed pandas version: 1.4.4 (✓)
# Installed scikit-learn version: 1.0.2 (✓)
# Installed matplotlib version: 3.5.2 (✓)
# Installed seaborn version: 0.11.2 (✓)
# Installed scipy version: 1.9.1 (✓)
# Installed spacy version: 3.4.2 (✓)

# %% [markdown]
# <h2>Exercise 1</h2>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 1.1. [5 Points]</b>
#     <ul>
#         <li>Plot the image of a tulip named <code>flower.jpg</code> (you will find this image in the folder <code>resources</code>).</li>
#     </ul>
# </div>

# %%
image_path = "resources/flower.jpg"

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 1.2. [5 Points]</b>
#     <ul>
#         <li>Load the image and print its dimensions (you will see that height and length/width are different to those from the image used in the lecture notebook).</li>
#     </ul>
# </div>

# %%
u2.plot_image(image_path)

img = imread(image_path)
print(img.shape)
# Out:
# (961, 1280, 3)

# %% [markdown]
# <h2>Exercise 2</h2>
#
# By using the functions from `u2_utils.py` and working with the flower image, perform the tasks below:

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.1. [3 Points]</b>
#     <ul>
#         <li>Plot the image with $\alpha = 60\%$.</li>
#     </ul>
# </div>

# %%
u2.plot_image_rgba(image_path, alpha=0.6)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.2. [3 Points]</b>
#     <ul>
#         <li>Plot the image by cropping it so that the flower is in the center of the (cropped) image and the distances to the borders are roughly equal.</li>
#     </ul>
# </div>

# %%
u2.plot_cropped_image(image_path, left=400, top=120, width=800, height=750)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.3. [5 Points]</b>
#     <ul>
#         <li>Plot the image channels as well as the histograms for each color channel in the image.</li>
#     </ul>
# </div>

# %%
u2.plot_image_channels_rgb(image_path)
u2.plot_color_histograms(image_path)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 2.4. [5 Points]</b>
#     <ul>
#         <li>Try to find good <b>color threshold</b> values to segment the image so the flower is separated from the background.</li>
#         <li>Note: The result does not need to be precise.</li>
#     </ul>
# </div>

# %%
u2.segment_image(image_path, lower_threshold_r=120, upper_threshold_g=140)

# %% [markdown]
# <h2>Exercise 3</h2>
#
# With the functions from the file `u2_utils.py`, as shown in the lecture notebook, perform the tasks below:

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.1. [10 Points]</b>
#     <ul>
#         <li>Generate three sine waves (all of them with a duration of 1.2 second, at a sampling rate of 28000 Hz) with the following frequencies: 440 Hz, 554.37 Hz and 659.25 Hz (in music terms, this is called an A major chord, here with the notes A4, C#5 and E5).</li>
#         <li>Then, add them together into a complex sound, plot the wave with <code>u2.plot_wave(...)</code> and generate a player to listen to it.</li>
#     </ul>
# </div>

# %%
T = 1.2
sampling_rate = 28000

points_of_wave_1 = u2.generate_wave(440, T, sampling_rate)
points_of_wave_2 = u2.generate_wave(554.37, T, sampling_rate) 
points_of_wave_3 = u2.generate_wave(659.25, T, sampling_rate) 

added_points_of_wave = points_of_wave_1 + points_of_wave_2 + points_of_wave_3

u2.plot_wave(added_points_of_wave, T, sampling_rate)
ipd.Audio(added_points_of_wave, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 3.2. [5 Points]</b>
#     <ul>
#         <li>Use the <code>u2.apply_fourier_transform(...)</code> function to apply the discrete Fourier transform (DFT) to this complex sound and plot the output, i.e., decompose the complex sound into the original sine waves. Choose a meaningful maximum frequency when plotting the spectrum.</li>
#     </ul>
# </div>

# %%
ft_added_points = u2.apply_fourier_transform(added_points_of_wave)
u2.plot_spectrum(ft_added_points, sampling_rate, max_freq= 1150)

# %% [markdown]
# <h2>Exercise 4</h2>
#
# By using the functions `u2.read_wav_file(...)` and `u2.apply_fourier_transform(...)` from `u2_utils.py`, perform the task below:

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 4.1. [10 Points]</b>
#     <ul>
#         <li>Read the audio file named <code>audio.wav</code> from the <code>resources</code> folder.</li>
#         <li>Apply Fourier analysis and plot the resulting spectrum.</li>
#     </ul>
# </div>

# %%
sound_path = "resources/audio.wav"
u2.read_wav_file(sound_path) 

T = 1
f = 440
sampling_rate = 24000 
points_of_wave  = u2.generate_wave(f, T , sampling_rate)

ft = u2.apply_fourier_transform(points_of_wave)
u2.plot_spectrum(ft, sampling_rate, max_freq=1000)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 4.2. [5 Points]</b>
#     <ul>
#         <li>Identify the frequencies of the three hidden sine waves.</li>
#         <li>Hint: Adapt <code>max_freq</code> from the <code>u2.plot_spectrum(...)</code> function above.</li>
#     </ul>
# </div>

# %%
points_audio, sampling_rate_audio = u2.read_wav_file(sound_path, time=T)

spectrogram_audio = u2.compute_spectrogram(points_audio)
spectrogram_audio.shape
# Out:
# (53, 513)

# %% [markdown]
# <h2>Exercise 5</h2>

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 5.1. [5 Points]</b>
#     <ul>
#         <li>Download the word embedding model and load it by using the <code>spacy</code> library.</li>
#     </ul>
# </div>

# %%
# !python -m spacy download en_core_web_md
word_embedding_english = spacy.load('en_core_web_md')
# Out:
# Collecting en-core-web-md==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.4.1/en_core_web_md-3.4.1-py3-none-any.whl (42.8 MB)
#      ---------------------------------------- 42.8/42.8 MB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\ayseb\anaconda3\lib\site-packages (from en-core-web-md==3.4.1) (3.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.10)
# Requirement already satisfied: packaging>=20.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (21.3)
# Requirement already satisfied: setuptools in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (63.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.4.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.1.5)
# Requirement already satisfied: jinja2 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.10.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.3.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.6.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.21.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.28.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ayseb\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ayseb\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\ayseb\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\ayseb\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayseb\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ayseb\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayseb\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ayseb\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (1.26.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ayseb\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ayseb\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.7.9)
# Requirement already satisfied: colorama in c:\users\ayseb\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ayseb\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ayseb\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-md==3.4.1) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 5.2. [10 Points]</b>
#     <ul>
#         <li>Evaluate which two words have a higher similarity: "exercise" and "fitness" or "candy" and "fitness".</li>
#         <li>Then, print out the result.</li>
#         <li>Hint: You could use an if-else statement to make the comparison (feel free to investigate this option on the Internet). Otherwise, simply evaluate both similarities manually and print the higher one.</li>
#     </ul>
# </div>

# %%
exercise = word_embedding_english('exercise')
candy = word_embedding_english('candy')
fitness = word_embedding_english('fitness') 

exercise.similarity(candy)
# Out:
# 0.033104083220015096

# %%
exercise = word_embedding_english('exercise')
candy = word_embedding_english('candy')
fitness = word_embedding_english('fitness') 

exercise.similarity(fitness)
# Out:
# 0.65191334762107

# %% [markdown]
# <h2>Exercise 6</h2>
#
# With the functions from the file `u2_utils.py`, including `u2.apply_tsne(...)`, i.e., the function to apply the t-SNE algorithm for dimensionality reduction already described in the first lecture, perform the tasks below:

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 6.1. [5 Points]</b>
#     <ul>
#         <li>Following the example given in the lecture notebook, create a list containing these words: "exercise", "fitness", "gym", "lifting", "weights", "squat", "candy", "chocolate", "gummi bears", "sugar", "sweet", "cake", "star", "night", "sky", "moon", "dark", "cold", "wind".</li>
#         <li>Hint: A list can be created with <code>my_list = [...]</code>, where <code>...</code> is the content.</li>
#     </ul>
# </div>

# %%
my_list = ["exercise", "fitness", "gym", "lifting", "weights", "squat", "candy", "chocolate", "gummi bears", "sugar", "sweet", "cake", "star", "night", "sky", "moon", "dark", "cold", "wind"]

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 6.2. [5 Points]</b>
#     <ul>
#         <li>Get the embeddings of the words and display the result data frame.</li>
#     </ul>
# </div>

# %%
word_embedding_english = spacy.load("en_core_web_md")

df_embeddings = u2.get_word_vectors(word_embedding_english, my_list)
df_embeddings
# Out:
#                  0         1        2         3        4         5    \
# exercise     0.10294  2.404100 -3.67800  0.629330  1.18930  0.640920
# fitness      3.70780  2.510700 -3.08450  1.340300  2.95120 -1.444200
# gym          4.60040  3.562000 -0.17496  1.345700 -1.39680 -0.766280
# lifting      1.45460  0.808330 -2.84970  4.035200  1.01070 -1.299200
# weights     -1.77410  1.819800 -2.78550  7.870300  2.37580 -1.702100
# squat        2.43760  4.331100 -3.04700  2.901100  0.48204  3.688300
# candy       -1.46080 -1.200600 -5.19130  3.935000 -0.93009 -4.535100
# chocolate   -0.75251 -3.348000 -2.92930  3.677300  0.67698 -4.622100
# gummi bears  1.39535  1.437045 -6.25565  2.117900  1.68900 -3.325150
# sugar        2.43350 -2.447600 -1.44910  3.883100  1.47290 -6.940300
# gummi bears  4.152400 -3.038800 -4.616675  4.685815  2.07410 -1.976175
# sugar        1.764200 -4.675600 -1.501200 -0.263730  5.02320  2.232400
# sweet        0.813240 -4.583000  0.467290 -2.656100  3.26140  4.476900
# cake        -1.320700 -2.676800 -1.924600  0.661320  3.09130  1.758300
# star        -3.579100  3.235200 -2.742500 -4.036600  3.60660  2.632000
# night        4.778800 -1.210700 -8.510200  2.230600  0.11542 -2.203700
# sky          4.235000 -1.842700  0.369470  1.316500  1.16500 -1.392800
# moon         2.434100  1.241100 -1.213500 -0.426290 -1.04640 -1.188000
# dark         5.267600  0.592540 -3.259600 -1.185500  2.00110  1.769100
# cold         5.452700 -4.098900 -8.684500 -0.273370  0.21958  7.865700
# wind         0.728540 -1.362000 -6.651800  1.622300 -2.16050  4.282500
#
#                  298       299
# exercise    -4.03910  1.364100
# fitness     -3.21150  3.925200
# gym         -2.06810 -1.463500
# lifting     -2.68510 -0.553810
# weights     -1.48840 -1.918900
# squat       -2.27430 -0.047475
# candy       -0.27158 -0.696060
# chocolate   -0.14004  1.398000
# gummi bears -2.63014  0.520950
# sugar       -1.82080 -0.528310
# sweet       -3.01940  1.425400
# cake         1.97170  2.721000
# star        -1.68180  1.371000
# night        1.17480  1.973300
# sky         -3.91250  0.484840
# moon        -5.11340 -0.806150
# dark        -6.84930 -0.612550
# cold         2.95060  3.329000
# wind        -2.51310  4.683200
#
# [19 rows x 300 columns]

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 6.3. [7 Points]</b>
#     <ul>
#         <li>Down-project the 300-dimensional representation of each word to 2 dimensions by applying the t-SNE method, i.e., the function <code>u2.apply_tsne(...)</code>.</li>
#         <li>Then, plot it in a 2D representation by using the function <code>u2.plot_word_embeddings_2d(...)</code>.</li>
#         <li>Look for a fitting <code>perplexity</code> value in order to group the words into meaningful clusters.</li>
#         <li>Note: Setting the seed for the random number generator <code>np.random.seed(seed=...)</code> is not necessary but useful if you want to ensure reproducible results.</li>
#     </ul>
# </div>

# %%
np.random.seed(seed=22)
embeddings_pca_2d = u2.apply_tsne(n_components=2, data=df_embeddings)
u2.plot_word_embeddings_2d(embeddings_tsne_2d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_70988\2526362109.py in <module>
#       1 np.random.seed(seed=22)
#       2 embeddings_pca_2d = u2.apply_tsne(n_components=2, data=df_embeddings)
# ----> 3 u2.plot_word_embeddings_2d(embeddings_tsne_2d)
#
# NameError: name 'embeddings_tsne_2d' is not defined

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 6.4. [7 Points]</b>
#     <ul>
#         <li>Verify that the perplexity was correct by applying the PCA down-projection method and plotting the result in a 2D representation (this will clearly show the different clusters).</li>
#     </ul>
# </div>

# %%
embeddings_pca_2d = u2.apply_pca(n_components=2, data=df_embeddings)
u2.plot_word_embeddings_2d(embeddings_pca_2d)

# %% [markdown]
# <div class="alert alert-warning">
#     <b>Exercise 6.5. [5 Points]</b>
#     <ul>
#         <li>How many (main) clusters are there?</li>
#     </ul>
# </div>

# %% [markdown]
# your answer here
